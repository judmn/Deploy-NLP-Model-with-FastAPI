# %% [markdown]
# <a href="https://colab.research.google.com/github/judmn/Deploy-NLP-Model-with-FastAPI/blob/main/Cyberview_BPI_%7C_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Brief
# This is a survey project conducted for Cyberview Sdn Bhd, a Tech hub developer that oversees Cyberjaya ecosystem, for its annual Brand Perception Index tracking. It seeks the opinion of the general public, as well as Cyberview's stakeholders with a target of **700 Completed Responses (CR)**.
#
# The requirements are as follow:
#
# Online (90%): 630 CR
# Face-to-face (10%): 70 CR
#
# Additionally, the **Online** responses has the following CR requirement:
#
# Online - Public: 480 CR
# Online - Stakeholders: 150 CR
#
# From the 10% Face-to-face (70 CR):
#   - Working adults: 40 CR
#   - MMU students: 30 CR
#
# Also, there's also a location-based requirement, as follows:
#
# Cyberjaya (30%): 210 CR
# Klang Valley (50%): 350 CR
# JB & Penang (20%): 140 CR
#
# `Update as at 30/01/2024:`
# It stands at 45 CR for stakeholders. Since it's difficult to achieve the 150 CR target, the client decided to back-up remaining CRs with respondents from Cyberjaya, with the following breakdown:
#
# -  20 working adults
# -  30 students in universities around Cyberjaya
#
# Data processing steps for this can be referred in `Responses from SurveyMonkey GSheet - 2nd Form` section.

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from typing import Optional

pd.set_option('display.max_rows', None)

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

import warnings
warnings.filterwarnings('ignore')

# %%
# Import google sheet using its url and convert it into DataFrame
def import_gsheet(url: str, sheet: str = 'Sheet1') -> pd.DataFrame:
  """
  Import data from a specific GSheet worksheet
  """

  gsheet = gc.open_by_url(url).worksheet(sheet)
  gsheet_values = gsheet.get_all_values()

  # Convert list into dataframe
  df = pd.DataFrame(gsheet_values[1:], columns=gsheet_values[0])

  # Replace blank cells as np.nan, else they won't be recognized as null values
  df = df.replace(['', 'null'], [np.nan, np.nan])

  return df

# %% [markdown]
# # Responses from SurveyMonkey GSheet - 1st Form
#
# Things to note:
# The responses are imported from SurveyMonkey platform into Google Sheet via SurveyMonkey extension. However, the answers to the question `Which of the following do you think is the Cyberview logo?`, which uses logo images, are not imported properly by the extension. The only way to process the results is to download them separately from SurveyMonkey and upload it here for concatenation.

# %% [markdown]
# ## Import data

# %%
raw = import_gsheet(url = 'https://docs.google.com/spreadsheets/d/1dXu_pKaVhWYPlGdjv79faEgmx_ptcSYKQGjVWcd788w/',
                    sheet='Cyberview Brand Perception Index Survey 2024')

raw['Response ID'] = raw['Response ID'].astype('int64')

raw.set_index('Response ID', inplace=True)

# Keep only completed responses, CR
cr = raw[raw['Response Status'] == 'completed']

# Decode Collector ID for source tracking
cr['Collector ID'] = cr['Collector ID'].replace(['454722632', '454701149', '454722561'], ['F2F', 'Online', 'Stakeholders'])

cr.head(3)
# Out:
#                      Date Created        Date Modified       IP Address  \
# Response ID
# 118513780738  2024-01-16 17:22:55  2024-01-16 22:47:11  161.142.155.162
# 118513799025  2024-01-16 17:58:56   2024-01-21 7:48:30     60.50.200.23
# 118513808111  2024-01-16 18:17:23  2024-01-16 22:45:43     60.50.200.23
#
#              Duration (sec) Response Status         Email    First Name  \
# Response ID
# 118513780738          19455       completed  Not Answered  Not Answered
# 118513799025         395373       completed  Not Answered  Not Answered
# 118513808111          16100       completed  Not Answered  Not Answered
#
#                  Last Name Collector ID Collector Type  ...  \
# Response ID                                             ...
# 118513780738  Not Answered       Online        weblink  ...
# 118513799025  Not Answered       Online        weblink  ...
# 118513808111  Not Answered       Online        weblink  ...
#
#              Cyberview menyediakan perkhidmatan pelanggan yang cekap dan pantas.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Cyberview mempromosikan dan menyebarkan maklumat tentang Cyberjaya dan tawaran Cyberview dengan berkesan.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                         Neither Agree nor Disagree
# 118513808111                         Neither Agree nor Disagree
#
#              Cyberview adalah organisasi pilihan saya untuk mencapai matlamat dan keperluan saya.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Cyberview ialah organisasi pilihan saya untuk bekerjasama/berkolaborasi  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Saya akan mengesyorkan Cyberview kepada rakan dan keluarga saya.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Cyberview sangat responsif, cekap, berorientasikan hasil dan membawa perubahan.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Cyberview menunjukkan nilai teguh iaitu jujur, bersemangat dan menunjukkan integriti yang tinggi.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Cyberview terbuka kepada kerjasama dalam memperkasakan pelanggan dan komunitinya.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Cyberview konsisten dan mempunyai rasa tanggungjawab yang tinggi.  \
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
#              Cyberview merupakan organisasi yang proaktif dan mahir dalam merealisasikan sesuatu sehingga mencapai kejayaan.
# Response ID
# 118513780738                                       Not Answered
# 118513799025                                              Agree
# 118513808111                                              Agree
#
# [3 rows x 130 columns]

# %%
'''
Split responses between English & Malay version for Malay -> English translation

There are some invalid responses where respondent answered both English & Malay versions, which isn't supposed to happen.
Therefore, the conditions for this filtering has to include checking the other version to have `Not Answered` value in the first question.
'''

# English responses
cr_eng = cr.loc[(cr['Choose your preferred language to answer this survey.'] == 'English') & (cr['Lokasi pekerjaan (jika masih bekerja) / Lokasi tempat tinggal (jika tidak bekerja)'] == 'Not Answered'), 'IP Address':'Cyberview is a go-getter organisation and makes things happen.']

# BM responses
cr_bm = pd.concat([
    cr.loc[(cr['Choose your preferred language to answer this survey.'] == 'Bahasa Melayu') & (cr['Work location (if you\'re in active employment) / Residential location (if you\'re not in the labor force)'] == 'Not Answered'), 'IP Address':'Choose your preferred language to answer this survey.'],
    cr.loc[(cr['Choose your preferred language to answer this survey.'] == 'Bahasa Melayu') & (cr['Work location (if you\'re in active employment) / Residential location (if you\'re not in the labor force)'] == 'Not Answered'), 'Lokasi pekerjaan (jika masih bekerja) / Lokasi tempat tinggal (jika tidak bekerja)':]
    ], axis='columns')

# %%
# Confirm that both English & BM versions has the same no. of columns
print(cr_eng.shape[1] == cr_bm.shape[1])
# Out:
# True

# %%
# Convert BM questionnaire into English
cr_bm.columns = cr_eng.columns # Both versions have the same questionnaire sequence

# %%
# Combine both dataframes
cr_all = pd.concat([cr_eng, cr_bm], axis='index')

# %%
# Keep required columns only
ip_address = cr_all[['IP Address']]

collector_id = cr_all[['Collector ID']]

phone_no = cr_all[['Phone No. (for e-wallet token distribution) [format: 60123456789]']]

questions = cr_all.loc[:, 'Work location (if you\'re in active employment) / Residential location (if you\'re not in the labor force)':]

cr_all_trim = pd.concat([ip_address, collector_id, phone_no, questions], axis='columns')

# %%
# Drop the question on logo recognition
cr_all_trim.drop(columns=['Which of the following do you think is the Cyberview logo?'], inplace=True)

# %% [markdown]
# ## Translate responses in BM to English

# %%
# Translation
translate = {'Selangor (selain Cyberjaya)': 'Selangor (other than Cyberjaya)',
             'Lelaki': 'Male',
             'Perempuan': 'Female',
             'Melayu': 'Malay',
             'Cina': 'Chinese',
             'India': 'Indian',
             '57 dan ke atas': '57 and older',
             'Pelajar': 'Student',
             'Profesional': 'Professionals',
             'Pekerja kolar putih': 'White collar',
             'Pekerja kolar biru': 'Blue collar',
             'Bekerja sendiri': 'Self-employed',
             'Pemilik perniagaan': 'Business owners',
             'Pesara': 'Retiree',
             'Lain-lain': 'Others',
             'Syarikat berasaskan teknologi (hampir keseluruhan)':'Mostly tech-based company',
             'Syarikat berasaskan teknologi (separa)': 'Partially tech-based company',
             'Syarikat tidak berasaskan teknologi':'Non tech-based company',
             'A) Kurang daripada 50':'A) Less than 50',
             'F) 1001 dan ke atas':'F) 1001 and more',
             'Pengurusan':'Management',
             'Pengurusan pertengahan (middle management)':'Middle Management',
             'Pemantauan / Ketua Pasukan':'Supervisory / Team Leader',
             'Sokongan dan penyelarasan (Eksekutif dan ke bawah)':'Support and Coordination (Executive and lower)',
             'Saya tidak mempunyai sebarang hubungan dengan Cyberview':'I don’t have any relationship with Cyberview',
             'Penyewa atau pelanggan Cyberview':'Cyberview\'s client / tenant',
             'Pembekal perkhidmatan':'Service provider',
             'Rakan kongsi program teknologi':'Tech Programme partner',
             'Rakan kongsi perniagaan':'Business partner',
             'Saya tahu tentang Cyberview tetapi kurang pasti akan apa yang mereka lakukan':'I know about Cyberview but not sure what Cyberview does',
             'Saya tidak pernah mendengar / tidak tahu tentang Cyberview sebelum menjawab kaji selidik ini':'I have not heard of / did not know about Cyberview before this survey',
             'Saya tahu tentang Cyberview dan faham akan jenis perniagaan mereka':'I know about Cyberview and understand their nature of business',
             'Pemaju hab teknologi yang memantau ekosistem Cyberjaya':'Tech hub developer that oversees Cyberjaya ecosystem',
             'Pemaju utama di Cyberjaya':'A master developer for Cyberjaya',
             'Pengurus bandar siber':'A cybercity manager',
             'Pemaju hartanah':'A property developer',
             'Pemilik tanah Cyberjaya':'The landowner of Cyberjaya',
             'Tiada di atas / Saya kurang pasti':'None of the above / I’m not sure'
             }

# %%
# Apply translation
cr_all_trim.replace(translate, inplace=True)

# %%
# cr_all_trim['Race'].unique()

# %%
# Filter out non-Malaysian
cr_all_trim = cr_all_trim.loc[cr_all_trim['Race'].isin(['Malay', 'Chinese', 'Indian', 'Bumiputera Sabah/Sarawak', 'Orang Asal', 'Punjabi', 'Sikh'])]

# %%
# Sanity check on all values
for col in cr_all_trim.columns:
  if col not in ['Response ID', 'IP Address', 'Phone No. (for e-wallet token distribution) [format: 60123456789]']:
    print(cr_all_trim[col].value_counts(normalize=False))
    print('\n')
# Out:
# Online          796
# F2F              82
# Stakeholders     47
# Name: Collector ID, dtype: int64
#
#
# Cyberjaya                          386
# Selangor (other than Cyberjaya)    169
# Kuala Lumpur                       149
# Pulau Pinang                       104
# Johor Bahru                         60
# Putrajaya                           57
# Name: Work location (if you're in active employment) / Residential location (if you're not in the labor force), dtype: int64
#
#
# Male      465
# Female    460
# Name: Gender, dtype: int64
#
#
# Malay                       580
# Chinese                     232
# Indian                       92
# Bumiputera Sabah/Sarawak     17
# Sikh                          2
# Punjabi                       1
# Orang Asal                    1
# Name: Race, dtype: int64
#
#
# 25-40           519
# 41-56           270
# 57 and older     93
# 18-24            43
# Name: Age range, dtype: int64
#
#
# Professionals      397
# White collar       157
# Self-employed       97
# Others              90
# Student             54
# Retiree             53
# Business owners     49
# Blue collar         28
# Name: Occupation - What is your profession?, dtype: int64
#
#
# B) RM3,440 - RM5,249     220
# A) Less than RM3,440     201
# D) RM7,690 - RM11,819    182
# C) RM5,250 - RM7,689     176
# E) RM11,820 and above    146
# Name: Household monthly income category, dtype: int64
#
#
# Information, Technology and Communication                                                                                    205
# Education                                                                                                                    118
# Finance and Insurance/Takaful Activities                                                                                      70
# Professional, Scientific and Technical Activities                                                                             64
# Manufacturing                                                                                                                 59
# Administrative and Support Service Activities                                                                                 58
# Human Health and Social Work Activities                                                                                       53
# Accommodation and Food Service Activities                                                                                     51
# Transportation and Storage                                                                                                    43
# Construction                                                                                                                  34
# Arts, Entertainment and Recreation                                                                                            32
# Real Estate Activities                                                                                                        27
# Public Administration and Defense, Compulsory Social Security                                                                 25
# Wholesale and Retail Trade; Repair of Motor Vehicles and Motorcycles                                                          23
# Activities of Households as Employers, Undifferentiated Goods and Services Producing Activities of Households for Own Use     17
# Electricity, Gas, Steam and Air Conditioning Supply                                                                           13
# Activities of Extraterritorial Organizations and Bodies                                                                       10
# Water supply, Sewerage, Waste Management and Remediation Activities                                                           10
# Agriculture, Forestry and Fishing                                                                                              5
# Mining and Quarrying                                                                                                           4
# Wholesale and Retail Trade, Repair of Motor Vehicles and Motorcycles                                                           4
# Name: Industry – What is your nature of business?, dtype: int64
#
#
# Partially tech-based company    340
# Non tech-based company          293
# Mostly tech-based company       292
# Name: Which of the following best describes the company that you are working in?, dtype: int64
#
#
# A) Less than 50     304
# F) 1001 and more    261
# B) 50 – 100          93
# D) 201 – 500         92
# E) 501 – 1000        89
# C) 101 – 200         86
# Name: Size of company – What is the size of your company? Please include all the employees in your company across all branches in Malaysia, dtype: int64
#
#
# Support and Coordination (Executive and lower)    348
# Management                                        244
# Middle Management                                 181
# Supervisory / Team Leader                         152
# Name: Role in the company – Which of the following best describes your role in the company when it comes to the management of the business?, dtype: int64
#
#
# I don’t have any relationship with Cyberview    780
# Cyberview's client / tenant                      79
# Service provider                                 24
# Cyberjaya stakeholder                            20
# Tech Programme partner                           13
# Business partner                                  9
# Name: Relation with Cyberview: What is your relationship with Cyberview?, dtype: int64
#
#
# I know about Cyberview but not sure what Cyberview does                  433
# I know about Cyberview and understand their nature of business           255
# I have not heard of / did not know about Cyberview before this survey    237
# Name: Which of the following best describes your impression of Cyberview?, dtype: int64
#
#
# Tech hub developer that oversees Cyberjaya ecosystem    423
# A master developer for Cyberjaya                        197
# None of the above / I’m not sure                        142
# A property developer                                     75
# A cybercity manager                                      50
# The landowner of Cyberjaya                               38
# Name: Which of the following do you think is the primary role of Cyberview?, dtype: int64
#
#
# FALSE    666
# TRUE     259
# Name: Where have you seen or heard about Cyberview? | Online search, dtype: int64
#
#
# TRUE     464
# FALSE    461
# Name: Where have you seen or heard about Cyberview? | Social media, dtype: int64
#
#
# FALSE    740
# TRUE     185
# Name: Where have you seen or heard about Cyberview? | Cyberview website, dtype: int64
#
#
# FALSE    908
# TRUE      17
# Name: Where have you seen or heard about Cyberview? | Radio advertisement, dtype: int64
#
#
# FALSE    822
# TRUE     103
# Name: Where have you seen or heard about Cyberview? | Online news, dtype: int64
#
#
# FALSE    737
# TRUE     188
# Name: Where have you seen or heard about Cyberview? | Billboard, dtype: int64
#
#
# FALSE    868
# TRUE      57
# Name: Where have you seen or heard about Cyberview? | Cyberview Electronic Direct Mailer/ newsletter, dtype: int64
#
#
# FALSE    760
# TRUE     165
# Name: Where have you seen or heard about Cyberview? | Friends and families, dtype: int64
#
#
# Not Answered                                                           842
# None                                                                     5
# Work                                                                     4
# Survey                                                                   2
# none                                                                     2
# This survey                                                              2
# No                                                                       2
# Offline                                                                  1
# Through enquiries                                                        1
# It's in Cyberjaya                                                        1
# Been to cyber Jaya saw the logo                                          1
# News coverage                                                            1
# Through event organised by Cyberview                                     1
# Landlord and also in prime news (tv)                                     1
# I bumped into it while driving around cyberjaya                          1
# On my way back home                                                      1
# Android                                                                  1
# Never                                                                    1
# Right now                                                                1
# Never heard before :-(                                                   1
# SK Cyberjaya                                                             1
# I pass by your office everyday                                           1
# Physical building across rekascape                                       1
# Pejabat                                                                  1
# Kajiselidik                                                              1
# Iklan jalan                                                              1
# Bangunan pejabat di Cyberjaya                                            1
# Di cyberjaya                                                             1
# Dalam cyberjaya                                                          1
# Lihat bangunan cyberview                                                 1
# Cyberjaya                                                                1
# St work                                                                  1
# depan office                                                             1
# worked with company involved with cyberjaya township development         1
# I live in Cyberjaya                                                      1
# I saw cyberview building whenever i go out or come inside cyberjaya      1
# Networking                                                               1
# in real life                                                             1
# no                                                                       1
# In Cyberjaya                                                             1
# The landmark( the building)                                              1
# Cyberview resort                                                         1
# this survey                                                              1
# i live in Cyberjaya                                                      1
# friends                                                                  1
# Working                                                                  1
# I live in cyberjaya                                                      1
# Will pass by cyberView on my way back Home                               1
# From this survey                                                         1
# formerly MDEC, part of the eco system                                    1
# Their building                                                           1
# Building name                                                            1
# Office                                                                   1
# Trade fairs                                                              1
# Former CoPlace 2 tenant                                                  1
# Drive by the office                                                      1
# I stay at cyberjaya                                                      1
# Around my house                                                          1
# Former tenant eb3                                                        1
# Event                                                                    1
# Passing by home                                                          1
# The building                                                             1
# Vaguely seen the logo before but didn't know that it is cyberview        1
# my office building, MKN Embassy                                          1
# Non                                                                      1
# Near to workplace                                                        1
# I live in Cyberjaya                                                      1
# It's nearby my house                                                     1
# Cyberjaya Farmers Market                                                 1
# Never heard                                                              1
# Went to the cyberview resort couple of times                             1
# Building logo in cyberjaya                                               1
# Bangunan cyberview                                                       1
# Name: Where have you seen or heard about Cyberview? | Other (please state), dtype: int64
#
#
# FALSE    804
# TRUE     121
# Name: Which of the following services offerred by Cyberview are you familiar with? | Investor relations services, dtype: int64
#
#
# TRUE     494
# FALSE    431
# Name: Which of the following services offerred by Cyberview are you familiar with? | Tech hub development and management services, dtype: int64
#
#
# FALSE    734
# TRUE     191
# Name: Which of the following services offerred by Cyberview are you familiar with? | Industry development initiatives, dtype: int64
#
#
# FALSE    517
# TRUE     408
# Name: Which of the following services offerred by Cyberview are you familiar with? | Cyberjaya city management services, dtype: int64
#
#
# FALSE                               595
# Not Answered                        183
# TRUE                                127
# None                                  3
# Tidak pasti                           2
# FB                                    1
# Hotel                                 1
# Pemilik hartanah utama cyberjaya      1
# Tak tahu                              1
# tidak pasti                           1
# Cyberview Lodge Resort & Spa          1
# Saya tidak tahu                       1
# Resort n spa                          1
# Hotel dan dewan kenduri               1
# Tidak tahu                            1
# tak tahu                              1
# Tak pasti                             1
# NONE                                  1
# HOTEL                                 1
# Perhotelan                            1
# Name: Which of the following services offerred by Cyberview are you familiar with? | Others, dtype: int64
#
#
# Agree                         443
# Neither Agree nor Disagree    270
# Strongly Agree                174
# Strongly Disagree              27
# Disagree                       11
# Name: Cyberview develops and is in-charge of the Cyberjaya new masterplan., dtype: int64
#
#
# Agree                         498
# Neither Agree nor Disagree    230
# Strongly Agree                162
# Strongly Disagree              18
# Disagree                       17
# Name: Cyberview plays a pivotal role in bringing tech investments into Cyberjaya., dtype: int64
#
#
# Agree                         495
# Neither Agree nor Disagree    220
# Strongly Agree                174
# Strongly Disagree              20
# Disagree                       16
# Name: Cyberview forges strong partnerships with tech ecosystem partners to strengthen Cyberjaya’s position as a Global Technology Hub., dtype: int64
#
#
# Agree                         472
# Neither Agree nor Disagree    264
# Strongly Agree                153
# Strongly Disagree              19
# Disagree                       17
# Name: Cyberview provides a one-stop centre for investment facilitation through Cyberjaya Investment and Services Centre., dtype: int64
#
#
# Agree                         480
# Neither Agree nor Disagree    217
# Strongly Agree                185
# Strongly Disagree              26
# Disagree                       17
# Name: Cyberview leads the transformation of Cyberjaya into a Global Technology Hub., dtype: int64
#
#
# Agree                         473
# Neither Agree nor Disagree    221
# Strongly Agree                182
# Disagree                       29
# Strongly Disagree              20
# Name: Cyberview enables Cyberjaya as a smart city and living lab to pilot innovations., dtype: int64
#
#
# Agree                         478
# Neither Agree nor Disagree    241
# Strongly Agree                169
# Strongly Disagree              21
# Disagree                       16
# Name: Cyberview plays a key role in providing development programmes for startups and tech companies., dtype: int64
#
#
# Agree                         473
# Neither Agree nor Disagree    257
# Strongly Agree                158
# Disagree                       19
# Strongly Disagree              18
# Name: Cyberview forges strong partnerships with startups and tech community through collaborative efforts to take them to the next level., dtype: int64
#
#
# FALSE    806
# TRUE     119
# Name: My interaction with Cyberview is / has been for the following service(s): | Project management (for property and infrastructure development), dtype: int64
#
#
# FALSE    714
# TRUE     211
# Name: My interaction with Cyberview is / has been for the following service(s): | Technology hub and smart city projects, dtype: int64
#
#
# FALSE    805
# TRUE     120
# Name: My interaction with Cyberview is / has been for the following service(s): | Startups and SME development programmes, dtype: int64
#
#
# FALSE    847
# TRUE      78
# Name: My interaction with Cyberview is / has been for the following service(s): | Investor relations services, dtype: int64
#
#
# FALSE    724
# TRUE     201
# Name: My interaction with Cyberview is / has been for the following service(s): | Cyberjaya city management, dtype: int64
#
#
# FALSE    655
# TRUE     270
# Name: My interaction with Cyberview is / has been for the following service(s): | Cyberjaya promotions, dtype: int64
#
#
# FALSE    571
# TRUE     354
# Name: My interaction with Cyberview is / has been for the following service(s): | Others, dtype: int64
#
#
# Agree                         497
# Neither Agree nor Disagree    228
# Strongly Agree                160
# Strongly Disagree              20
# Disagree                       20
# Name: Cyberview acts as a key player in attracting and growing tech investments in Cyberjaya., dtype: int64
#
#
# Agree                         487
# Neither Agree nor Disagree    234
# Strongly Agree                153
# Strongly Disagree              26
# Disagree                       25
# Name: Cyberview is proactive in strengthening Cyberjaya’s ecosystem towards elevating Cyberjaya into a Global Tech Hub through its new masterplan, smart city and living lab initiatives., dtype: int64
#
#
# Agree                         467
# Neither Agree nor Disagree    234
# Strongly Agree                176
# Disagree                       27
# Strongly Disagree              21
# Name: Cyberview has the capacity and capability to elevate Cyberjaya into a Global Tech Hub., dtype: int64
#
#
# Agree                         478
# Neither Agree nor Disagree    263
# Strongly Agree                148
# Disagree                       21
# Strongly Disagree              15
# Name: Cyberview provides effective development programmes for startups and tech companies., dtype: int64
#
#
# Agree                         424
# Neither Agree nor Disagree    343
# Strongly Agree                122
# Strongly Disagree              18
# Disagree                       18
# Name: Cyberview provides efficient and fast client services., dtype: int64
#
#
# Agree                         450
# Neither Agree nor Disagree    276
# Strongly Agree                139
# Disagree                       33
# Strongly Disagree              27
# Name: Cyberview effectively promotes and disseminates information about Cyberjaya and Cyberview’s offerings., dtype: int64
#
#
# Neither Agree nor Disagree    418
# Agree                         345
# Strongly Agree                108
# Disagree                       32
# Strongly Disagree              22
# Name: Cyberview is my preferred organisation to go to, to achieve my goals and needs., dtype: int64
#
#
# Neither Agree nor Disagree    377
# Agree                         377
# Strongly Agree                122
# Disagree                       29
# Strongly Disagree              20
# Name: Cyberview is my preferred organisation to work with/collaborate with, dtype: int64
#
#
# Agree                         427
# Neither Agree nor Disagree    317
# Strongly Agree                132
# Disagree                       26
# Strongly Disagree              23
# Name: I would recommend Cyberview to my friends and families., dtype: int64
#
#
# Agree                         399
# Neither Agree nor Disagree    372
# Strongly Agree                107
# Disagree                       24
# Strongly Disagree              23
# Name: Cyberview is responsive, alert, is result-oriented and creates change., dtype: int64
#
#
# Agree                         401
# Neither Agree nor Disagree    366
# Strongly Agree                117
# Strongly Disagree              22
# Disagree                       19
# Name: Cyberview demonstrates strong values of being honest, passionate and demonstrates high integrity., dtype: int64
#
#
# Agree                         472
# Neither Agree nor Disagree    292
# Strongly Agree                128
# Strongly Disagree              20
# Disagree                       13
# Name: Cyberview is open to collaboration to empower its clients and community., dtype: int64
#
#
# Agree                         415
# Neither Agree nor Disagree    337
# Strongly Agree                135
# Strongly Disagree              20
# Disagree                       18
# Name: Cyberview is consistent and has a strong sense of accountability., dtype: int64
#
#
# Agree                         418
# Neither Agree nor Disagree    328
# Strongly Agree                132
# Disagree                       24
# Strongly Disagree              23
# Name: Cyberview is a go-getter organisation and makes things happen., dtype: int64

# %% [markdown]
# # Responses from SurveyMonkey GSheet - 2nd Form

# %% [markdown]
# ## Import data

# %%
raw_student = import_gsheet(url = 'https://docs.google.com/spreadsheets/d/1dXu_pKaVhWYPlGdjv79faEgmx_ptcSYKQGjVWcd788w/',
                            sheet='Cyberview Brand Perception Index Survey 2024 (Students)')

raw_student.set_index('Response ID', inplace=True)

# Keep only completed responses, CR
cr_student = raw_student.loc[raw_student['Response Status'] == 'completed']

# Decode Collector ID respectively
cr_student['Collector ID'] = cr_student['Collector ID'].replace(['429889948'], ['Online - Student'])

# cr_student.head(3)

# %%
# cr_student['Which university you are currently studying at?'].value_counts(normalize=True)

# %%
# Drop questions that don't exist in the 1st Form
cr_student.drop(columns=['Which university you are currently studying at?',
                         'Industry – What is the nature of your study?',
                         'Which of the following do you think is the Cyberview logo?'],
                inplace=True)

# %% [markdown]
# ## Manully insert columns with default values

# %%
# Manually insert `Age range` column
cr_student['Age range'] = '18-24'

# Manually insert `Occupation - What is your profession?` column
cr_student['Occupation - What is your profession?'] = 'Student'

# Manually insert location
cr_student['Work location (if you\'re in active employment) / Residential location (if you\'re not in the labor force)'] = 'Cyberjaya'

# %%
# Keep required columns only
ip_address_2 = cr_student[['IP Address']]

collector_id_2 = cr_student[['Collector ID']]

questions_2 = cr_student.loc[:,'Phone No. (for e-wallet token distribution) [format: 60123456789]':]

cr_student_trim = pd.concat([ip_address_2, collector_id_2, questions_2], axis='columns')

# %%
# Filter out non-Malaysian
cr_student_trim = cr_student_trim.loc[cr_student_trim['Race'].isin(['Malay', 'Chinese', 'Indian', 'Bumiputera Sabah/Sarawak', 'Orang Asal', 'Punjabi', 'Sikh'])]

# %%
cr_student_trim.head(3)
# Out:
#                    IP Address      Collector ID  \
# Response ID
# 114521482199  161.142.154.164  Online - Student
# 114521484514   202.184.154.31  Online - Student
# 114521487087   42.153.128.121  Online - Student
#
#              Phone No. (for e-wallet token distribution) [format: 60123456789]  \
# Response ID
# 114521482199                                        60129823856
# 114521484514                                       601137091353
# 114521487087                                       601163193829
#
#               Gender     Race Household monthly income category  \
# Response ID
# 114521482199    Male    Malay              A) Less than RM3,440
# 114521484514    Male  Chinese              B) RM3,440 - RM5,249
# 114521487087  Female    Malay              A) Less than RM3,440
#
#              Relation with Cyberview: What is your relationship with Cyberview?  \
# Response ID
# 114521482199       I don’t have any relationship with Cyberview
# 114521484514       I don’t have any relationship with Cyberview
# 114521487087       I don’t have any relationship with Cyberview
#
#              Which of the following best describes your impression of Cyberview?  \
# Response ID
# 114521482199  I know about Cyberview but not sure what Cyber...
# 114521484514  I have not heard of / did not know about Cyber...
# 114521487087  I know about Cyberview but not sure what Cyber...
#
#              Which of the following do you think is the primary role of Cyberview?  \
# Response ID
# 114521482199                                A cybercity manager
# 114521484514                                A cybercity manager
# 114521487087                   None of the above / I’m not sure
#
#              Where have you seen or heard about Cyberview? | Online search  \
# Response ID
# 114521482199                                              FALSE
# 114521484514                                              FALSE
# 114521487087                                              FALSE
#
#               ...  \
# Response ID   ...
# 114521482199  ...
# 114521484514  ...
# 114521487087  ...
#
#              Cyberview is my preferred organisation to work with/collaborate with  \
# Response ID
# 114521482199                                     Strongly Agree
# 114521484514                         Neither Agree nor Disagree
# 114521487087                                              Agree
#
#              I would recommend Cyberview to my friends and families.  \
# Response ID
# 114521482199                                              Agree
# 114521484514                                              Agree
# 114521487087                                     Strongly Agree
#
#              Cyberview is responsive, alert, is result-oriented and creates change.  \
# Response ID
# 114521482199                                     Strongly Agree
# 114521484514                                              Agree
# 114521487087                                              Agree
#
#              Cyberview demonstrates strong values of being honest, passionate and demonstrates high integrity.  \
# Response ID
# 114521482199                                     Strongly Agree
# 114521484514                         Neither Agree nor Disagree
# 114521487087                                              Agree
#
#              Cyberview is open to collaboration to empower its clients and community.  \
# Response ID
# 114521482199                                     Strongly Agree
# 114521484514                                              Agree
# 114521487087                                     Strongly Agree
#
#              Cyberview is consistent and has a strong sense of accountability.  \
# Response ID
# 114521482199                                     Strongly Agree
# 114521484514                                              Agree
# 114521487087                                              Agree
#
#              Cyberview is a go-getter organisation and makes things happen.  \
# Response ID
# 114521482199                                     Strongly Agree
# 114521484514                                              Agree
# 114521487087                                              Agree
#
#              Age range Occupation - What is your profession?  \
# Response ID
# 114521482199     18-24                               Student
# 114521484514     18-24                               Student
# 114521487087     18-24                               Student
#
#              Work location (if you're in active employment) / Residential location (if you're not in the labor force)
# Response ID
# 114521482199                                          Cyberjaya
# 114521484514                                          Cyberjaya
# 114521487087                                          Cyberjaya
#
# [3 rows x 55 columns]

# %% [markdown]
# # Combine both forms

# %%
cr_combined = pd.concat([cr_all_trim, cr_student_trim], axis='index', sort=False)

print(cr_combined.shape)
# Out:
# (971, 59)

# %%
for col in cr_combined.columns:
  if col not in ['Response ID', 'IP Address', 'Phone No. (for e-wallet token distribution) [format: 60123456789]']:
    print(cr_combined[col].value_counts())
    print('\n')
# Out:
# Online              796
# F2F                  82
# Stakeholders         47
# Online - Student     46
# Name: Collector ID, dtype: int64
#
#
# Cyberjaya                          432
# Selangor (other than Cyberjaya)    169
# Kuala Lumpur                       149
# Pulau Pinang                       104
# Johor Bahru                         60
# Putrajaya                           57
# Name: Work location (if you're in active employment) / Residential location (if you're not in the labor force), dtype: int64
#
#
# Female    489
# Male      482
# Name: Gender, dtype: int64
#
#
# Malay                       607
# Chinese                     243
# Indian                      100
# Bumiputera Sabah/Sarawak     17
# Sikh                          2
# Punjabi                       1
# Orang Asal                    1
# Name: Race, dtype: int64
#
#
# 25-40           519
# 41-56           270
# 57 and older     93
# 18-24            89
# Name: Age range, dtype: int64
#
#
# Professionals      397
# White collar       157
# Student            100
# Self-employed       97
# Others              90
# Retiree             53
# Business owners     49
# Blue collar         28
# Name: Occupation - What is your profession?, dtype: int64
#
#
# B) RM3,440 - RM5,249     226
# A) Less than RM3,440     224
# D) RM7,690 - RM11,819    188
# C) RM5,250 - RM7,689     183
# E) RM11,820 and above    150
# Name: Household monthly income category, dtype: int64
#
#
# Information, Technology and Communication                                                                                    205
# Education                                                                                                                    118
# Finance and Insurance/Takaful Activities                                                                                      70
# Professional, Scientific and Technical Activities                                                                             64
# Manufacturing                                                                                                                 59
# Administrative and Support Service Activities                                                                                 58
# Human Health and Social Work Activities                                                                                       53
# Accommodation and Food Service Activities                                                                                     51
# Transportation and Storage                                                                                                    43
# Construction                                                                                                                  34
# Arts, Entertainment and Recreation                                                                                            32
# Real Estate Activities                                                                                                        27
# Public Administration and Defense, Compulsory Social Security                                                                 25
# Wholesale and Retail Trade; Repair of Motor Vehicles and Motorcycles                                                          23
# Activities of Households as Employers, Undifferentiated Goods and Services Producing Activities of Households for Own Use     17
# Electricity, Gas, Steam and Air Conditioning Supply                                                                           13
# Activities of Extraterritorial Organizations and Bodies                                                                       10
# Water supply, Sewerage, Waste Management and Remediation Activities                                                           10
# Agriculture, Forestry and Fishing                                                                                              5
# Mining and Quarrying                                                                                                           4
# Wholesale and Retail Trade, Repair of Motor Vehicles and Motorcycles                                                           4
# Name: Industry – What is your nature of business?, dtype: int64
#
#
# Partially tech-based company    340
# Non tech-based company          293
# Mostly tech-based company       292
# Name: Which of the following best describes the company that you are working in?, dtype: int64
#
#
# A) Less than 50     304
# F) 1001 and more    261
# B) 50 – 100          93
# D) 201 – 500         92
# E) 501 – 1000        89
# C) 101 – 200         86
# Name: Size of company – What is the size of your company? Please include all the employees in your company across all branches in Malaysia, dtype: int64
#
#
# Support and Coordination (Executive and lower)    348
# Management                                        244
# Middle Management                                 181
# Supervisory / Team Leader                         152
# Name: Role in the company – Which of the following best describes your role in the company when it comes to the management of the business?, dtype: int64
#
#
# I don’t have any relationship with Cyberview    824
# Cyberview's client / tenant                      81
# Service provider                                 24
# Cyberjaya stakeholder                            20
# Tech Programme partner                           13
# Business partner                                  9
# Name: Relation with Cyberview: What is your relationship with Cyberview?, dtype: int64
#
#
# I know about Cyberview but not sure what Cyberview does                  460
# I know about Cyberview and understand their nature of business           262
# I have not heard of / did not know about Cyberview before this survey    249
# Name: Which of the following best describes your impression of Cyberview?, dtype: int64
#
#
# Tech hub developer that oversees Cyberjaya ecosystem    439
# A master developer for Cyberjaya                        206
# None of the above / I’m not sure                        151
# A property developer                                     80
# A cybercity manager                                      57
# The landowner of Cyberjaya                               38
# Name: Which of the following do you think is the primary role of Cyberview?, dtype: int64
#
#
# FALSE    703
# TRUE     268
# Name: Where have you seen or heard about Cyberview? | Online search, dtype: int64
#
#
# TRUE     487
# FALSE    484
# Name: Where have you seen or heard about Cyberview? | Social media, dtype: int64
#
#
# FALSE    782
# TRUE     189
# Name: Where have you seen or heard about Cyberview? | Cyberview website, dtype: int64
#
#
# FALSE    953
# TRUE      18
# Name: Where have you seen or heard about Cyberview? | Radio advertisement, dtype: int64
#
#
# FALSE    864
# TRUE     107
# Name: Where have you seen or heard about Cyberview? | Online news, dtype: int64
#
#
# FALSE    769
# TRUE     202
# Name: Where have you seen or heard about Cyberview? | Billboard, dtype: int64
#
#
# FALSE    912
# TRUE      59
# Name: Where have you seen or heard about Cyberview? | Cyberview Electronic Direct Mailer/ newsletter, dtype: int64
#
#
# FALSE    798
# TRUE     173
# Name: Where have you seen or heard about Cyberview? | Friends and families, dtype: int64
#
#
# Not Answered                                                           885
# None                                                                     5
# Work                                                                     4
# Survey                                                                   2
# none                                                                     2
# No                                                                       2
# This survey                                                              2
# I bumped into it while driving around cyberjaya                          1
# SK Cyberjaya                                                             1
# Offline                                                                  1
# Through enquiries                                                        1
# It's in Cyberjaya                                                        1
# News coverage                                                            1
# Been to cyber Jaya saw the logo                                          1
# St work                                                                  1
# Through event organised by Cyberview                                     1
# Landlord and also in prime news (tv)                                     1
# On my way back home                                                      1
# Android                                                                  1
# Never                                                                    1
# Right now                                                                1
# Physical building across rekascape                                       1
# I saw cyberview building whenever i go out or come inside cyberjaya      1
# I pass by your office everyday                                           1
# Networking                                                               1
# drove pass through cyberview resort                                      1
# Seen in places in Cyberjaya                                              1
# Bangunan cyberview                                                       1
# Kajiselidik                                                              1
# Iklan jalan                                                              1
# Bangunan pejabat di Cyberjaya                                            1
# Di cyberjaya                                                             1
# Dalam cyberjaya                                                          1
# Lihat bangunan cyberview                                                 1
# Pejabat                                                                  1
# Cyberjaya                                                                1
# depan office                                                             1
# worked with company involved with cyberjaya township development         1
# I live in Cyberjaya                                                      1
# no                                                                       1
# Never heard before :-(                                                   1
# Around my house                                                          1
# in real life                                                             1
# formerly MDEC, part of the eco system                                    1
# Drive by the office                                                      1
# Former CoPlace 2 tenant                                                  1
# Trade fairs                                                              1
# Office                                                                   1
# Building name                                                            1
# Their building                                                           1
# From this survey                                                         1
# The landmark( the building)                                              1
# Will pass by cyberView on my way back Home                               1
# I live in cyberjaya                                                      1
# Working                                                                  1
# friends                                                                  1
# i live in Cyberjaya                                                      1
# this survey                                                              1
# Cyberview resort                                                         1
# I stay at cyberjaya                                                      1
# Former tenant eb3                                                        1
# Event                                                                    1
# Passing by home                                                          1
# The building                                                             1
# Vaguely seen the logo before but didn't know that it is cyberview        1
# my office building, MKN Embassy                                          1
# Non                                                                      1
# Near to workplace                                                        1
# I live in Cyberjaya                                                      1
# It's nearby my house                                                     1
# Cyberjaya Farmers Market                                                 1
# Never heard                                                              1
# In Cyberjaya                                                             1
# Building logo in cyberjaya                                               1
# Went to the cyberview resort couple of times                             1
# Around Cyberjaya                                                         1
# Name: Where have you seen or heard about Cyberview? | Other (please state), dtype: int64
#
#
# FALSE    847
# TRUE     124
# Name: Which of the following services offerred by Cyberview are you familiar with? | Investor relations services, dtype: int64
#
#
# TRUE     515
# FALSE    456
# Name: Which of the following services offerred by Cyberview are you familiar with? | Tech hub development and management services, dtype: int64
#
#
# FALSE    769
# TRUE     202
# Name: Which of the following services offerred by Cyberview are you familiar with? | Industry development initiatives, dtype: int64
#
#
# FALSE    540
# TRUE     431
# Name: Which of the following services offerred by Cyberview are you familiar with? | Cyberjaya city management services, dtype: int64
#
#
# FALSE                               632
# Not Answered                        183
# TRUE                                136
# None                                  3
# Tidak pasti                           2
# FB                                    1
# Hotel                                 1
# Pemilik hartanah utama cyberjaya      1
# Tak tahu                              1
# tidak pasti                           1
# Cyberview Lodge Resort & Spa          1
# Saya tidak tahu                       1
# Resort n spa                          1
# Hotel dan dewan kenduri               1
# Tidak tahu                            1
# tak tahu                              1
# Tak pasti                             1
# NONE                                  1
# HOTEL                                 1
# Perhotelan                            1
# Name: Which of the following services offerred by Cyberview are you familiar with? | Others, dtype: int64
#
#
# Agree                         468
# Neither Agree nor Disagree    286
# Strongly Agree                179
# Strongly Disagree              27
# Disagree                       11
# Name: Cyberview develops and is in-charge of the Cyberjaya new masterplan., dtype: int64
#
#
# Agree                         526
# Neither Agree nor Disagree    241
# Strongly Agree                168
# Strongly Disagree              19
# Disagree                       17
# Name: Cyberview plays a pivotal role in bringing tech investments into Cyberjaya., dtype: int64
#
#
# Agree                         525
# Neither Agree nor Disagree    232
# Strongly Agree                178
# Strongly Disagree              20
# Disagree                       16
# Name: Cyberview forges strong partnerships with tech ecosystem partners to strengthen Cyberjaya’s position as a Global Technology Hub., dtype: int64
#
#
# Agree                         494
# Neither Agree nor Disagree    280
# Strongly Agree                160
# Strongly Disagree              19
# Disagree                       18
# Name: Cyberview provides a one-stop centre for investment facilitation through Cyberjaya Investment and Services Centre., dtype: int64
#
#
# Agree                         506
# Neither Agree nor Disagree    232
# Strongly Agree                190
# Strongly Disagree              26
# Disagree                       17
# Name: Cyberview leads the transformation of Cyberjaya into a Global Technology Hub., dtype: int64
#
#
# Agree                         502
# Neither Agree nor Disagree    230
# Strongly Agree                188
# Disagree                       31
# Strongly Disagree              20
# Name: Cyberview enables Cyberjaya as a smart city and living lab to pilot innovations., dtype: int64
#
#
# Agree                         503
# Neither Agree nor Disagree    256
# Strongly Agree                174
# Strongly Disagree              21
# Disagree                       17
# Name: Cyberview plays a key role in providing development programmes for startups and tech companies., dtype: int64
#
#
# Agree                         501
# Neither Agree nor Disagree    271
# Strongly Agree                160
# Disagree                       21
# Strongly Disagree              18
# Name: Cyberview forges strong partnerships with startups and tech community through collaborative efforts to take them to the next level., dtype: int64
#
#
# FALSE    848
# TRUE     123
# Name: My interaction with Cyberview is / has been for the following service(s): | Project management (for property and infrastructure development), dtype: int64
#
#
# FALSE    749
# TRUE     222
# Name: My interaction with Cyberview is / has been for the following service(s): | Technology hub and smart city projects, dtype: int64
#
#
# FALSE    849
# TRUE     122
# Name: My interaction with Cyberview is / has been for the following service(s): | Startups and SME development programmes, dtype: int64
#
#
# FALSE    891
# TRUE      80
# Name: My interaction with Cyberview is / has been for the following service(s): | Investor relations services, dtype: int64
#
#
# FALSE    757
# TRUE     214
# Name: My interaction with Cyberview is / has been for the following service(s): | Cyberjaya city management, dtype: int64
#
#
# FALSE    691
# TRUE     280
# Name: My interaction with Cyberview is / has been for the following service(s): | Cyberjaya promotions, dtype: int64
#
#
# FALSE    600
# TRUE     371
# Name: My interaction with Cyberview is / has been for the following service(s): | Others, dtype: int64
#
#
# Agree                         529
# Neither Agree nor Disagree    237
# Strongly Agree                165
# Strongly Disagree              20
# Disagree                       20
# Name: Cyberview acts as a key player in attracting and growing tech investments in Cyberjaya., dtype: int64
#
#
# Agree                         516
# Neither Agree nor Disagree    245
# Strongly Agree                158
# Strongly Disagree              27
# Disagree                       25
# Name: Cyberview is proactive in strengthening Cyberjaya’s ecosystem towards elevating Cyberjaya into a Global Tech Hub through its new masterplan, smart city and living lab initiatives., dtype: int64
#
#
# Agree                         490
# Neither Agree nor Disagree    247
# Strongly Agree                186
# Disagree                       27
# Strongly Disagree              21
# Name: Cyberview has the capacity and capability to elevate Cyberjaya into a Global Tech Hub., dtype: int64
#
#
# Agree                         507
# Neither Agree nor Disagree    274
# Strongly Agree                154
# Disagree                       21
# Strongly Disagree              15
# Name: Cyberview provides effective development programmes for startups and tech companies., dtype: int64
#
#
# Agree                         446
# Neither Agree nor Disagree    361
# Strongly Agree                127
# Disagree                       19
# Strongly Disagree              18
# Name: Cyberview provides efficient and fast client services., dtype: int64
#
#
# Agree                         475
# Neither Agree nor Disagree    286
# Strongly Agree                147
# Disagree                       36
# Strongly Disagree              27
# Name: Cyberview effectively promotes and disseminates information about Cyberjaya and Cyberview’s offerings., dtype: int64
#
#
# Neither Agree nor Disagree    440
# Agree                         363
# Strongly Agree                112
# Disagree                       34
# Strongly Disagree              22
# Name: Cyberview is my preferred organisation to go to, to achieve my goals and needs., dtype: int64
#
#
# Agree                         399
# Neither Agree nor Disagree    394
# Strongly Agree                126
# Disagree                       32
# Strongly Disagree              20
# Name: Cyberview is my preferred organisation to work with/collaborate with, dtype: int64
#
#
# Agree                         448
# Neither Agree nor Disagree    333
# Strongly Agree                140
# Disagree                       27
# Strongly Disagree              23
# Name: I would recommend Cyberview to my friends and families., dtype: int64
#
#
# Agree                         418
# Neither Agree nor Disagree    390
# Strongly Agree                114
# Disagree                       26
# Strongly Disagree              23
# Name: Cyberview is responsive, alert, is result-oriented and creates change., dtype: int64
#
#
# Agree                         426
# Neither Agree nor Disagree    380
# Strongly Agree                123
# Strongly Disagree              22
# Disagree                       20
# Name: Cyberview demonstrates strong values of being honest, passionate and demonstrates high integrity., dtype: int64
#
#
# Agree                         490
# Neither Agree nor Disagree    308
# Strongly Agree                139
# Strongly Disagree              20
# Disagree                       14
# Name: Cyberview is open to collaboration to empower its clients and community., dtype: int64
#
#
# Agree                         437
# Neither Agree nor Disagree    354
# Strongly Agree                141
# Strongly Disagree              20
# Disagree                       19
# Name: Cyberview is consistent and has a strong sense of accountability., dtype: int64
#
#
# Agree                         445
# Neither Agree nor Disagree    340
# Strongly Agree                138
# Disagree                       25
# Strongly Disagree              23
# Name: Cyberview is a go-getter organisation and makes things happen., dtype: int64

# %% [markdown]
# # Remove duplicates

# %%
# Since only a single TnG e-wallet will be given to each unique phone no., we need to ensure there's no phone no. duplicates
cr_combined.drop_duplicates(subset='Phone No. (for e-wallet token distribution) [format: 60123456789]', inplace=True)

print(f'CR after removing duplicates: {cr_combined.shape[0]}')
# Out:
# CR after removing duplicates: 966

# %%
ip_duplicate = cr_combined.loc[cr_combined.duplicated(subset='IP Address', keep=False)].sort_values(by='IP Address')

ip_duplicate['IP Address'].value_counts()
# Out:
# 115.135.28.103     7
# 103.61.127.165     5
# 103.253.105.52     4
# 49.124.200.218     3
# 183.171.175.39     3
# 202.187.67.197     3
# 45.121.38.30       3
# 175.142.80.150     3
# 113.210.90.213     3
# 183.171.175.119    2
# 45.121.38.28       2
# 45.121.38.26       2
# 27.125.248.68      2
# 219.92.18.205      2
# 58.71.165.6        2
# 183.171.191.136    2
# 60.48.168.110      2
# 103.253.105.16     2
# 161.142.156.67     2
# 172.225.181.81     2
# 103.253.105.44     2
# 161.142.154.184    2
# 161.142.154.169    2
# 14.192.196.43      2
# 120.138.95.7       2
# 120.138.95.0       2
# 113.211.210.249    2
# 113.211.110.118    2
# 113.210.50.104     2
# 110.159.85.172     2
# 60.53.34.8         2
# Name: IP Address, dtype: int64

# %% [markdown]
# # CR Monitoring

# %% [markdown]
# ## Location-based CR

# %%
cr_all_trim.loc[cr_all_trim['Occupation - What is your profession?'] != 'Student', 'Household monthly income category'].value_counts()
# Out:
# B) RM3,440 - RM5,249     218
# D) RM7,690 - RM11,819    179
# C) RM5,250 - RM7,689     175
# A) Less than RM3,440     158
# E) RM11,820 and above    141
# Name: Household monthly income category, dtype: int64

# %%
# If CR from working adults who are 'A) Less than RM3,440' in household income are removed
cr_all_rich = cr_all_trim.loc[(cr_all_trim['Occupation - What is your profession?'] != 'Student') & (cr_all_trim['Household monthly income category'] != 'A) Less than RM3,440')]

# %%
cr_all_rich['Work location (if you\'re in active employment) / Residential location (if you\'re not in the labor force)'].value_counts()
# Out:
# Cyberjaya                          294
# Kuala Lumpur                       129
# Selangor (other than Cyberjaya)    129
# Pulau Pinang                        68
# Putrajaya                           49
# Johor Bahru                         44
# Name: Work location (if you're in active employment) / Residential location (if you're not in the labor force), dtype: int64

# %% [markdown]
# ## F2F - Working adults

# %%
f2f = cr_all_trim.loc[(cr_all_trim['Collector ID'] == 'F2F') & (cr_all_trim['Occupation - What is your profession?'] != 'Student')]

print(f'CR: {f2f.shape[0]}')
# Out:
# CR: 43

# %% [markdown]
# ## F2F - Students

# %%
f2f_student = cr_combined.loc[(cr_combined['Collector ID'] == 'F2F') & (cr_combined['Occupation - What is your profession?'] == 'Student')]

print(f'CR: {f2f_student.shape[0]}')
# Out:
# CR: 39

# %% [markdown]
# ## Online
# CR requirement for online respondent: 480

# %%
online = cr_all_trim.loc[cr_all_trim['Collector ID'] == 'Online']

print(f'CR: {online.shape[0]}')
# Out:
# CR: 796

# %%
online['Work location (if you\'re in active employment) / Residential location (if you\'re not in the labor force)'].value_counts()
# Out:
# Cyberjaya                          293
# Selangor (other than Cyberjaya)    154
# Kuala Lumpur                       133
# Pulau Pinang                       104
# Johor Bahru                         60
# Putrajaya                           52
# Name: Work location (if you're in active employment) / Residential location (if you're not in the labor force), dtype: int64

# %%
pd.pivot_table(data = online,
               index='Work location (if you\'re in active employment) / Residential location (if you\'re not in the labor force)',
               columns='Occupation - What is your profession?',
               values='Collector ID',
               aggfunc='count')
# Out:
# Occupation - What is your profession?               Blue collar  \
# Work location (if you're in active employment) ...
# Cyberjaya                                                   5.0
# Johor Bahru                                                 3.0
# Kuala Lumpur                                                8.0
# Pulau Pinang                                                3.0
# Putrajaya                                                   2.0
# Selangor (other than Cyberjaya)                             4.0
#
# Occupation - What is your profession?               Business owners  Others  \
# Work location (if you're in active employment) ...
# Cyberjaya                                                      16.0    35.0
# Johor Bahru                                                     4.0     9.0
# Kuala Lumpur                                                    4.0     7.0
# Pulau Pinang                                                    4.0    13.0
# Putrajaya                                                       NaN     6.0
# Selangor (other than Cyberjaya)                                 4.0    10.0
#
# Occupation - What is your profession?               Professionals  Retiree  \
# Work location (if you're in active employment) ...
# Cyberjaya                                                   143.0      6.0
# Johor Bahru                                                  17.0      6.0
# Kuala Lumpur                                                 66.0      6.0
# Pulau Pinang                                                 35.0     14.0
# Putrajaya                                                    31.0      NaN
# Selangor (other than Cyberjaya)                              62.0     21.0
#
# Occupation - What is your profession?               Self-employed  Student  \
# Work location (if you're in active employment) ...
# Cyberjaya                                                    31.0      9.0
# Johor Bahru                                                  10.0      1.0
# Kuala Lumpur                                                 10.0      NaN
# Pulau Pinang                                                 19.0      1.0
# Putrajaya                                                     1.0      2.0
# Selangor (other than Cyberjaya)                              21.0      2.0
#
# Occupation - What is your profession?               White collar
# Work location (if you're in active employment) ...
# Cyberjaya                                                   48.0
# Johor Bahru                                                 10.0
# Kuala Lumpur                                                32.0
# Pulau Pinang                                                15.0
# Putrajaya                                                   10.0
# Selangor (other than Cyberjaya)                             30.0

# %% [markdown]
# ## Stakeholders Only
# CR requirement for stakeholders: 150

# %%
stakeholders = cr_all_trim.loc[cr_all_trim['Collector ID'] == 'Stakeholders']

print(f'CR: {stakeholders.shape[0]}')
# Out:
# CR: 47

# %%
# for col in stakeholders.columns:
#   if col not in ['IP Address', 'Phone No. (for e-wallet token distribution) [format: 60123456789]']:
#     print(stakeholders[col].value_counts())
#     print("\n")

# %% [markdown]
# # Manual Upload of Logo Recognition Responses
# The responses were downloaded from SurveyMonkey as `xls` format with the following filters:
#
# 1.  Completed responses only
# 2.  For question, only the question on logo recognition was chosen

# %%
import time

file_name = [
    'Cyberview_logo_060224.xlsx',
    'Cyberview_student_logo_060224.xlsx'
    ]

logo_df = []

for f in file_name:

  print(f'Processing {f} ..')

  logo = pd.read_excel(f)

  logo.rename(columns={'Respondent ID':'Response ID'}, inplace=True)

  logo['Response ID'] = logo['Response ID'].astype('int64')

  logo.set_index('Response ID', inplace=True)

  # Conditional processing for form with both BM & English versions
  if 'Antara berikut, yang manakah merupakan logo Cyberview?' in logo.columns:

    logo_eng = logo.loc[(logo['Which of the following do you think is the Cyberview logo?'].notnull()) & (logo['Antara berikut, yang manakah merupakan logo Cyberview?'].isnull()), ['Which of the following do you think is the Cyberview logo?']]

    logo_bm = logo.loc[(logo['Antara berikut, yang manakah merupakan logo Cyberview?'].notnull()) & (logo['Which of the following do you think is the Cyberview logo?'].isnull()), ['Antara berikut, yang manakah merupakan logo Cyberview?']]

    logo_bm.rename(columns={'Antara berikut, yang manakah merupakan logo Cyberview?':'Which of the following do you think is the Cyberview logo?'},
                  inplace=True)

    logo_bm.replace({'Tidak pasti': 'I\'m not sure'}, inplace=True)

    logo_all = pd.concat([logo_eng, logo_bm], axis='index', verify_integrity=True)

  else:
    logo_all = logo

  logo_all = logo_all[['Which of the following do you think is the Cyberview logo?']]

  logo_df.append(logo_all)

  print(f'Processing completed. ', end='')
  print(f'DF shape: {logo_all.shape}')
  time.sleep(1)

logo_combined = pd.concat(logo_df)

logo_combined.replace({'Image 1': 'Image 1 (MSC logo)',
                       'Image 2': 'Image 2 (Cyberview logo)',
                       'Image 3': 'Image 3 (Cyberjaya logo)',
                       'Image 4': 'Image 4 (Cyberview Resort & Spa)'
                       },
                      inplace=True)

print(display(logo_combined.head()))
print(logo_combined.value_counts())
# Out:
# Processing Cyberview_logo_060224.xlsx ..
# Processing completed. DF shape: (944, 1)
# Processing Cyberview_student_logo_060224.xlsx ..
# Processing completed. DF shape: (50, 1)
#              Which of the following do you think is the Cyberview logo?
# Response ID
# 118529091140                           Image 2 (Cyberview logo)
# 118528810037                           Image 2 (Cyberview logo)
# 118528730845                           Image 2 (Cyberview logo)
# 118528708168                           Image 2 (Cyberview logo)
# 118528693079                           Image 2 (Cyberview logo)
# None
# Which of the following do you think is the Cyberview logo?
# Image 2 (Cyberview logo)                                      643
# I'm not sure                                                  152
# Image 4 (Cyberview Resort & Spa)                              114
# Image 1 (MSC logo)                                             60
# Image 3 (Cyberjaya logo)                                       25
# dtype: int64

# %% [markdown]
# ## Join Logo Recognition question with main DF

# %%
# cr_combined.loc['118528453547']

# %%
# cr_merged = pd.merge(cr_combined, logo_combined, left_index=True, right_index=True)

# cr_merged.info()

# %% [markdown]
# # Brand Perception Index Calculation
# There's an Excel template given by the client for the BPI calculation. All we need is to input the count of each relevant responses accordingly, and the BPI and its sub-components (ie. Brand Awareness, Brand Association, etc.) will be calculated automatically.

# %% [markdown]
# ## Brand Awareness (Cyberview Logo)

# %%
logo_combined[['Which of the following do you think is the Cyberview logo?']].value_counts().to_frame(name='count').reset_index()
# Out:
#   Which of the following do you think is the Cyberview logo?  count
# 0                           Image 2 (Cyberview logo)            643
# 1                                       I'm not sure            152
# 2                   Image 4 (Cyberview Resort & Spa)            114
# 3                                 Image 1 (MSC logo)             60
# 4                           Image 3 (Cyberjaya logo)             25

# %% [markdown]
# ## Primary Role

# %%
primary_role = cr_combined[['Which of the following do you think is the primary role of Cyberview?']].value_counts().to_frame(name='count').reset_index()

primary_role
# Out:
#   Which of the following do you think is the primary role of Cyberview?  count
# 0  Tech hub developer that oversees Cyberjaya eco...                       438
# 1                   A master developer for Cyberjaya                       205
# 2                   None of the above / I’m not sure                       149
# 3                               A property developer                        79
# 4                                A cybercity manager                        57
# 5                         The landowner of Cyberjaya                        38

# %% [markdown]
# ## Brand Association

# %%
brand_assoc = [
    'Cyberview develops and is in-charge of the Cyberjaya new masterplan.',
    'Cyberview plays a pivotal role in bringing tech investments into Cyberjaya.',
    'Cyberview forges strong partnerships with tech ecosystem partners to strengthen Cyberjaya’s position as a Global Technology Hub.',
    'Cyberview provides a one-stop centre for investment facilitation through Cyberjaya Investment and Services Centre.',
    'Cyberview leads the transformation of Cyberjaya into a Global Technology Hub.',
    'Cyberview enables Cyberjaya as a smart city and living lab to pilot innovations.',
    'Cyberview plays a key role in providing development programmes for startups and tech companies.',
    'Cyberview forges strong partnerships with startups and tech community through collaborative efforts to take them to the next level.'
    ]

for q in brand_assoc:
  print(cr_combined[[q]].value_counts().to_frame(name='count').reset_index())
  print('\n')
# Out:
#   Cyberview develops and is in-charge of the Cyberjaya new masterplan.  count
# 0                                              Agree                      464
# 1                         Neither Agree nor Disagree                      286
# 2                                     Strongly Agree                      178
# 3                                  Strongly Disagree                       27
# 4                                           Disagree                       11
#
#
#   Cyberview plays a pivotal role in bringing tech investments into Cyberjaya.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    522
# 1    241
# 2    167
# 3     19
# 4     17
#
#
#   Cyberview forges strong partnerships with tech ecosystem partners to strengthen Cyberjaya’s position as a Global Technology Hub.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    522
# 1    231
# 2    177
# 3     20
# 4     16
#
#
#   Cyberview provides a one-stop centre for investment facilitation through Cyberjaya Investment and Services Centre.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    490
# 1    280
# 2    159
# 3     19
# 4     18
#
#
#   Cyberview leads the transformation of Cyberjaya into a Global Technology Hub.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    503
# 1    231
# 2    189
# 3     26
# 4     17
#
#
#   Cyberview enables Cyberjaya as a smart city and living lab to pilot innovations.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    499
# 1    229
# 2    187
# 3     31
# 4     20
#
#
#   Cyberview plays a key role in providing development programmes for startups and tech companies.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    500
# 1    255
# 2    173
# 3     21
# 4     17
#
#
#   Cyberview forges strong partnerships with startups and tech community through collaborative efforts to take them to the next level.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    497
# 1    271
# 2    159
# 3     21
# 4     18

# %% [markdown]
# ## Perceived Quality

# %%
quality = [
    'Cyberview acts as a key player in attracting and growing tech investments in Cyberjaya.',
    'Cyberview is proactive in strengthening Cyberjaya’s ecosystem towards elevating Cyberjaya into a Global Tech Hub through its new masterplan, smart city and living lab initiatives.',
    'Cyberview has the capacity and capability to elevate Cyberjaya into a Global Tech Hub.',
    'Cyberview provides effective development programmes for startups and tech companies.',
    'Cyberview provides efficient and fast client services.',
    'Cyberview effectively promotes and disseminates information about Cyberjaya and Cyberview’s offerings.'
    ]

for q in quality:
  print(cr_combined[[q]].value_counts().to_frame(name='count').reset_index())
  print('\n')
# Out:
#   Cyberview acts as a key player in attracting and growing tech investments in Cyberjaya.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    526
# 1    236
# 2    164
# 3     20
# 4     20
#
#
#   Cyberview is proactive in strengthening Cyberjaya’s ecosystem towards elevating Cyberjaya into a Global Tech Hub through its new masterplan, smart city and living lab initiatives.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    513
# 1    244
# 2    157
# 3     27
# 4     25
#
#
#   Cyberview has the capacity and capability to elevate Cyberjaya into a Global Tech Hub.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    486
# 1    247
# 2    185
# 3     27
# 4     21
#
#
#   Cyberview provides effective development programmes for startups and tech companies.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    503
# 1    274
# 2    153
# 3     21
# 4     15
#
#
#   Cyberview provides efficient and fast client services.  count
# 0                                              Agree        442
# 1                         Neither Agree nor Disagree        360
# 2                                     Strongly Agree        127
# 3                                           Disagree         19
# 4                                  Strongly Disagree         18
#
#
#   Cyberview effectively promotes and disseminates information about Cyberjaya and Cyberview’s offerings.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    471
# 1    285
# 2    147
# 3     36
# 4     27

# %% [markdown]
# ## Brand Preference

# %%
brand_pref = [
    'Cyberview is my preferred organisation to go to, to achieve my goals and needs.',
    'Cyberview is my preferred organisation to work with/collaborate with',
    'I would recommend Cyberview to my friends and families.'
    ]

for q in brand_pref:
  print(cr_combined[[q]].value_counts().to_frame(name='count').reset_index())
  print('\n')
# Out:
#   Cyberview is my preferred organisation to go to, to achieve my goals and needs.  \
# 0                         Neither Agree nor Disagree
# 1                                              Agree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    439
# 1    359
# 2    112
# 3     34
# 4     22
#
#
#   Cyberview is my preferred organisation to work with/collaborate with  count
# 0                                              Agree                      395
# 1                         Neither Agree nor Disagree                      393
# 2                                     Strongly Agree                      126
# 3                                           Disagree                       32
# 4                                  Strongly Disagree                       20
#
#
#   I would recommend Cyberview to my friends and families.  count
# 0                                              Agree         443
# 1                         Neither Agree nor Disagree         333
# 2                                     Strongly Agree         140
# 3                                           Disagree          27
# 4                                  Strongly Disagree          23

# %% [markdown]
# ## Brand Personality

# %%
brand_persona = [
    'Cyberview is responsive, alert, is result-oriented and creates change.',
    'Cyberview demonstrates strong values of being honest, passionate and demonstrates high integrity.',
    'Cyberview is open to collaboration to empower its clients and community.',
    'Cyberview is consistent and has a strong sense of accountability.',
    'Cyberview is a go-getter organisation and makes things happen.'
]

for q in brand_persona:
  print(cr_combined[[q]].value_counts().to_frame(name='count').reset_index())
  print('\n')
# Out:
#   Cyberview is responsive, alert, is result-oriented and creates change.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                           Disagree
# 4                                  Strongly Disagree
#
#    count
# 0    413
# 1    390
# 2    114
# 3     26
# 4     23
#
#
#   Cyberview demonstrates strong values of being honest, passionate and demonstrates high integrity.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    421
# 1    380
# 2    123
# 3     22
# 4     20
#
#
#   Cyberview is open to collaboration to empower its clients and community.  \
# 0                                              Agree
# 1                         Neither Agree nor Disagree
# 2                                     Strongly Agree
# 3                                  Strongly Disagree
# 4                                           Disagree
#
#    count
# 0    485
# 1    308
# 2    139
# 3     20
# 4     14
#
#
#   Cyberview is consistent and has a strong sense of accountability.  count
# 0                                              Agree                   432
# 1                         Neither Agree nor Disagree                   354
# 2                                     Strongly Agree                   141
# 3                                  Strongly Disagree                    20
# 4                                           Disagree                    19
#
#
#   Cyberview is a go-getter organisation and makes things happen.  count
# 0                                              Agree                441
# 1                         Neither Agree nor Disagree                340
# 2                                     Strongly Agree                137
# 3                                           Disagree                 25
# 4                                  Strongly Disagree                 23
